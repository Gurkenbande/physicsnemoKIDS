# %%
import xarray as xr

ds = xr.open_dataset("output/test_results.nc")
print(ds)

# %%
from vis import WeatherDownscalingVisualizer
import os 
# Create visualizations
print("\n" + "="*50)
print("Creating visualizations...")
print("="*50)

viz = WeatherDownscalingVisualizer(
    netcdf_path=os.path.join("/Users/emely/Uni/Lab4/Lab4/output/test_results.nc")
)


viz.create_summary_report(
    output_dir=os.path.join("/Users/emely/Uni/Lab4/Lab4/output/visualizations"),
)

viz.close()

print("All done! Check the output/visualizations folder for plots.")
