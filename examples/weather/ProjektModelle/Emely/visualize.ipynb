# %%
import xarray as xr

ds = xr.open_dataset("output/test_results.nc")
print(ds)
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:                           (lat: 448, lon: 448, sample: 205)
# Coordinates:
#     lon                               (lat, lon) float32 803kB ...
#     lat                               (lat, lon) float32 803kB ...
# Dimensions without coordinates: sample
# Data variables:
#     pred_maximum_radar_reflectivity   (sample, lat, lon) float32 165MB ...
#     truth_maximum_radar_reflectivity  (sample, lat, lon) float32 165MB ...
#     pred_temperature_2m               (sample, lat, lon) float32 165MB ...
#     truth_temperature_2m              (sample, lat, lon) float32 165MB ...
#     pred_eastward_wind_10m            (sample, lat, lon) float32 165MB ...
#     truth_eastward_wind_10m           (sample, lat, lon) float32 165MB ...
#     pred_northward_wind_10m           (sample, lat, lon) float32 165MB ...
#     truth_northward_wind_10m          (sample, lat, lon) float32 165MB ...
# Attributes:
#     description:  Weather downscaling model predictions
#     history:      Created 2026-02-08T20:44:02
#     source:       GNN4CD downscaling model

# %%
from vis import WeatherDownscalingVisualizer
import os 


viz = WeatherDownscalingVisualizer(
    netcdf_path=os.path.join("output/test_results.nc")
)


viz.create_summary_report(
    output_dir=os.path.join("output/visualizations"),
)
# Out:
# Found variables: ['maximum_radar_reflectivity', 'temperature_2m', 'eastward_wind_10m', 'northward_wind_10m']
